# %%
import torch
import numpy

# %%
size = 600

a = numpy.random.rand(size, size)
b = numpy.random.rand(size, size)

# %%
# %%timeit

x = numpy.dot(a,b)
# Out:
# 100 loops, best of 5: 14.1 ms per loop

# %%
# %%timeit

c = numpy.zeros((size,size))

for i in range(size):
  for j in range(size):
    for k in range(size):
      c[i,j] += a[i,k] * b[k,j]
# Out:
# 1 loop, best of 5: 2min 26s per loop

# %%
x = torch.cuda.FloatTensor([3.5])
x.type()
# Out:
# 'torch.cuda.FloatTensor'

# %%
x.device
# Out:
# device(type='cuda', index=0)

# %%
y = x * x
y
# Out:
# tensor([12.2500], device='cuda:0')

# %%
aa = torch.cuda.FloatTensor(a)
bb = torch.cuda.FloatTensor(b)

# %%
# %%timeit

cc = torch.matmul(aa, bb)
# Out:
# The slowest run took 79.37 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 5: 282 µs per loop

# %%
if torch.cuda.is_available():
  torch.set_default_tensor_type(torch.cuda.FloatTensor)
  print("using cuda:", torch.cuda.get_device_name(0))
  pass

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

device
# Out:
# using cuda: Tesla K80
# device(type='cuda')
